# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# # DUDAS!!!!
#
# * Cómo puedo eliminar 2 columnas de golpe
# * Parametros de outliers en boxplot

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# # Palabras Clave que Impulsan el Éxito: Un Estudio de 5-Minute Crafts

# %% [markdown]
# ### TEMA

# %% [markdown]
# Este proyecto se centra en analizar la **influencia de las palabras clave utilizadas en los títulos de los videos de 5-Minute Crafts** en el **número total de visitas** que reciben. 5-Minute Crafts es un canal de YouTube conocido por sus videos de estilo *"Do It Yoursel(DIY)*" y es uno de los canales más populares en la plataforma. A través de un análisis exhaustivo, examinaré cómo ciertas palabras o frases específicas en los títulos pueden atraer más atención y generar un mayor número de visitas.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Puede que tengas más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# ### Hipótesis principal:
# El uso de ciertas palabras clave en los títulos de los videos de 5-Minute Crafts está correlacionado con un mayor número de vistas totales.Es decir, algunas palabras o frases específicas pueden atraer más atención y generar más visitas.

# %% [markdown]
# ### Otras hipótesis:
#
# * La longitud de la palabra clave en el título de un video está correlacionada con el número de visitas que recibe.
# * El uso de palabras clave que sugieran acción, por ejemplo: "hazlo tú mismo", "aprende", "descubre", puede estar asociado con un aumento en las visitas.
# * Existe una correlación entre la duración de un video con el número total de visitas que recibe.
# * La proporción de palabras en mayúsculas y minúsculas en el título puede estar relacionada con la cantidad de visitas al video.
# * El sentimiento del título puede influir en el nivel de popularidad y número de visitas.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una breve descripción del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %% [markdown]
# Para poder hacer mi EDA voy a usar este dataset de Kaggle: **https://www.kaggle.com/datasets/shivamb/5minute-crafts-video-views-dataset/data**

# %% [markdown]
# Descripción: 5-Minute Crafts es un canal de YouTube de estilo DIY propiedad de TheSoul Publishing. Desde octubre de 2021, es el noveno canal con más suscriptores de la plataforma y uno de los más vistos. El canal ha suscitado críticas por sus inusuales y potencialmente peligrosos trucos y su dependencia del clickbait. Independientemente de las críticas, los vídeos de 5-Minute Crafts tienen muchas visitas.
#
# En este conjunto de datos se recoge un registro completo de los títulos de los vídeos de los canales de youtube de 5-Minute Craft, junto con muchas otras metacaracterísticas de los títulos. También contiene: visualizaciones totales del vídeo, duración, activos desde, analisis de sentimiento, etc.

# %% [markdown]
# #### Notas con información de algunas columnas
#
# * Active_since_days: vídeo activo desde x días
# * Num_chars: caracteres totales del título del vídeo
# * Num_words: total de palabras en el título del vídeo
# * Num_punctuation: número de signos de puntuación
# * Num_words_uppercase: número de mayúsculas
# * Num_words_lowercase: número de minúsculas
# * Num_stopwords: "palabras vacías".Son palabras que para la recuperación de información y en el procesamiento del lenguaje natural debido a que no aporta un significado específico y no ayuda a distinguir un documento o fragmento de texto particular. Estas palabras suelen ser preposiciones, conjunciones, artículos y otros términos muy frecuentes en un idioma. Ejem: the, and,is,in,of...
# * Avg_word_len: longitud media de la palabra
# * Contain_digits: el título contiene dígitos
# * Startswith_digits: si el título empieza por un dígito
# * Title_sentiment: sentimiento del título del vídeo.  Significa lo positivo o negativo que es el título. Se calcula con la biblioteca textblob de python

# %%
import pandas as pd
five_minute_crafts = pd.read_csv(filepath_or_buffer="/Users/luna/Desktop/posibles/5-Minute Crafts.csv")

# %%
print(five_minute_crafts.shape) #Numero de filas y columnas
five_minute_crafts.head() # Los primeros 5 registros
# Out:
# (4978, 15)
#         video_id                                              title  \
# 0  v=XHTofu5wbbM  SUPER LAZY LIFE HACKS || Cool Hacks To Make Yo...
# 1  v=HGxx0umIQvk  YUM! EASY SMART FOOD HACKS || Tasty Recipes Fo...
# 2  v=Tt4RMk3Ih04                  HELPFUL LIFE HACKS FOR YOUR HOUSE
# 3  v=A2MTydM5e58  USEFUL HACKS FOR YOUR HOME || Simple Tips That...
# 4  v=_halJ4yrmGQ  ARE YOU A CRAFTY MOM? Amazing Parenting Hacks ...
#
#    active_since_days  duration_seconds  total_views  num_chars  num_words  \
# 0                 22               623       295614         60         12
# 1                  1               739       130544         87         17
# 2                  1               960        17834         33          6
# 3                 30               833      3128867         66         12
# 4                 15              3600      4210362         56         10
#
#    num_punctuation  num_words_uppercase  num_words_lowercase  num_stopwords  \
# ...

# %%
five_minute_crafts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4978 entries, 0 to 4977
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             4978 non-null   object
#  1   title                4978 non-null   object
#  2   active_since_days    4978 non-null   int64
#  3   duration_seconds     4978 non-null   int64
#  4   total_views          4978 non-null   int64
#  5   num_chars            4978 non-null   int64
#  6   num_words            4978 non-null   int64
#  7   num_punctuation      4978 non-null   int64
#  8   num_words_uppercase  4978 non-null   int64
#  9   num_words_lowercase  4978 non-null   int64
#  10  num_stopwords        4978 non-null   int64
#  11  avg_word_len         4978 non-null   float64
#  12  contain_digits       4978 non-null   int64
#  13  startswith_digits    4978 non-null   int64
#  14  title_sentiment      4978 non-null   float64
# ...

# %% [markdown]
# #### Datos faltantes
#
# No me falta ningún dato, ya que hay 4978 filas y cada columna contiene 4978 datos

# %% [markdown]
# #### Borrar columnas irrelevantes

# %%
# Borrar la columna video_id (no me sirven para nada los enlaces a los vídeos)
# También borro la columna active_since_days (no me sirve para nada saber desde cuando está eñ vídeo activo)
# No sé aún si me es relevante la columna de startswith_digits. La dejo de momento.
borrar_video_id = five_minute_crafts.drop('video_id',axis=1)
borrar_video_id
df = borrar_video_id.drop('active_since_days',axis=1)
df
# Out:
#                                                   title  duration_seconds  \
# 0     SUPER LAZY LIFE HACKS || Cool Hacks To Make Yo...               623
# 1     YUM! EASY SMART FOOD HACKS || Tasty Recipes Fo...               739
# 2                     HELPFUL LIFE HACKS FOR YOUR HOUSE               960
# 3     USEFUL HACKS FOR YOUR HOME || Simple Tips That...               833
# 4     ARE YOU A CRAFTY MOM? Amazing Parenting Hacks ...              3600
# ...                                                 ...               ...
# 4973  Amazing life hack; how to recycle old crayons ...                55
# 4974  How to DIY a magnetic memo holder l 5-MINUTE C...                52
# 4975  How to turn your old T-shirt into a pillowcase...                62
# 4976  3 tricks to clean without harsh chemicals l 5-...                81
# 4977  5 essential DIY hacks that you need to know  l...                73
#
#       total_views  num_chars  num_words  num_punctuation  num_words_uppercase  \
# ...

# %%
# Utilizo la columna title como índice
df = df.set_index('title')
df
# Out:
#                                                     duration_seconds  \
# title
# SUPER LAZY LIFE HACKS || Cool Hacks To Make You...               623
# YUM! EASY SMART FOOD HACKS || Tasty Recipes For...               739
# HELPFUL LIFE HACKS FOR YOUR HOUSE                                960
# USEFUL HACKS FOR YOUR HOME || Simple Tips That ...               833
# ARE YOU A CRAFTY MOM? Amazing Parenting Hacks A...              3600
# ...                                                              ...
# Amazing life hack; how to recycle old crayons l...                55
# How to DIY a magnetic memo holder l 5-MINUTE CR...                52
# How to turn your old T-shirt into a pillowcase ...                62
# 3 tricks to clean without harsh chemicals l 5-M...                81
# 5 essential DIY hacks that you need to know  l ...                73
#
#                                                     total_views  num_chars  \
# title
# ...

# %% [markdown]
# #### Comprobar si hay filas repetidas

# %%
filas_repetidas = df.duplicated()
print(filas_repetidas)
# Out:
# title
# SUPER LAZY LIFE HACKS || Cool Hacks To Make Your Life Easier                               False
# YUM! EASY SMART FOOD HACKS || Tasty Recipes For The Whole Family & Ideas To Avoid Fails    False
# HELPFUL LIFE HACKS FOR YOUR HOUSE                                                          False
# USEFUL HACKS FOR YOUR HOME || Simple Tips That Work Extremely Well                         False
# ARE YOU A CRAFTY MOM? Amazing Parenting Hacks And Crafts                                   False
#                                                                                            ...
# Amazing life hack; how to recycle old crayons l 5-MINUTE CRAFTS                            False
# How to DIY a magnetic memo holder l 5-MINUTE CRAFTS                                        False
# How to turn your old T-shirt into a pillowcase (NO SEWING) | 5-MINUTE CRAFTS               False
# 3 tricks to clean without harsh chemicals l 5-MINUTE CRAFTS                                False
# ...

# %%
total_filas_repetidas = filas_repetidas.sum()
print(f'Total de filas repetidas: {total_filas_repetidas}')
# Out:
# Total de filas repetidas: 0

# %% [markdown]
# #### Outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['duration_seconds', 'total_views', 'num_chars', 'num_words',
#        'num_punctuation', 'num_words_uppercase', 'num_words_lowercase',
#        'num_stopwords', 'avg_word_len', 'contain_digits', 'startswith_digits',
#        'title_sentiment'],
#       dtype='object')

# %%
plt.title('Duranción segundos')
plt.hist(df['duration_seconds'],edgecolor = 'black',linewidth=1)
plt.show()

# %%
plt.boxplot(df['duration_seconds'],vert=False) #vert=False es para que salga en horizontal
plt.show()

# %% [markdown]
# Para obtener los valores de los outliers tenemos que calcular los valores del primer y tercer cuartil

# %%
Q1 = df['duration_seconds'].quantile(0.25)
print("Primer cuartil",Q1)

Q3 = df['duration_seconds'].quantile(0.75)
print("Tercer cuartil",Q3)

rango_intercuartil = Q3-Q1
print("Rango Intercuartil", rango_intercuartil)

Mediana = df['duration_seconds'].median()
print('Mediana', Mediana)

Valor_Minimo = df['duration_seconds'].min()
print("Valor Mínimo", Valor_Minimo)

Valor_Maximo = df['duration_seconds'].max()
print("Valor Máximo",Valor_Maximo)
# Out:
# Primer cuartil 696.0
# Tercer cuartil 960.0
# Rango Intercuartil 264.0
# Mediana 867.0
# Valor Mínimo 11
# Valor Máximo 14880

# %% [markdown]
# Calcular los valores de los bigotes inferior y superior

# %%
binferior_calculado = (Q1-1.5*rango_intercuartil)
binferior_calculado
# Out:
# 300.0

# %%
bsuperior_calculado = (Q3+1.5*rango_intercuartil)
bsuperior_calculado
# Out:
# 1356.0

# %% [markdown]
# Ubicar las filas en las que se encuentran los outliers

# %%
ubicacion_outliers = (df['duration_seconds'] < binferior_calculado) | (df["duration_seconds"]> bsuperior_calculado)
ubicacion_outliers

# cuando es outlier es True
# Out:
# title
# SUPER LAZY LIFE HACKS || Cool Hacks To Make Your Life Easier                               False
# YUM! EASY SMART FOOD HACKS || Tasty Recipes For The Whole Family & Ideas To Avoid Fails    False
# HELPFUL LIFE HACKS FOR YOUR HOUSE                                                          False
# USEFUL HACKS FOR YOUR HOME || Simple Tips That Work Extremely Well                         False
# ARE YOU A CRAFTY MOM? Amazing Parenting Hacks And Crafts                                    True
#                                                                                            ...
# Amazing life hack; how to recycle old crayons l 5-MINUTE CRAFTS                             True
# How to DIY a magnetic memo holder l 5-MINUTE CRAFTS                                         True
# How to turn your old T-shirt into a pillowcase (NO SEWING) | 5-MINUTE CRAFTS                True
# 3 tricks to clean without harsh chemicals l 5-MINUTE CRAFTS                                 True
# ...

# %% [markdown]
# Imprimir los valores de los outliers

# %%
outliers = df[ubicacion_outliers]
print("\n Lista de Outliers \n", outliers)
# Out:
#  Lista de Outliers
#                                                      duration_seconds  \
# title
# ARE YOU A CRAFTY MOM? Amazing Parenting Hacks A...              3600
# 100+ HACKS & GADGETS FOR COOL PARENTS                           3600
# KID'S ROOM MAKEOVER IDEAS || Awesome Home Decor...              3660
# BRILLIANT LIFE HACKS FOR ANY SITUATION                          3600
# SOAP BUBBLES CHALLENGE with 5-MINUTE CRAFTS #sh...                12
# ...                                                              ...
# Amazing life hack; how to recycle old crayons l...                55
# How to DIY a magnetic memo holder l 5-MINUTE CR...                52
# How to turn your old T-shirt into a pillowcase ...                62
# 3 tricks to clean without harsh chemicals l 5-M...                81
# 5 essential DIY hacks that you need to know  l ...                73
#
#                                                     total_views  num_chars  \
# title
# ...

# %% [markdown]
# Ordenar los outliers (ascendente)

# %%
outliers_ordenados = outliers.sort_values("duration_seconds")
outliers_ordenados
# Out:
#                                                     duration_seconds  \
# title
# CANDY CHALLENGE FOR COUPLES 🍬 #shorts                             11
# SOAP BUBBLES CHALLENGE with 5-MINUTE CRAFTS #sh...                12
# HOW TO FILM COOKING HACKS 👩‍🍳 #shorts                             18
# WOW! 5-MINUTE CRAFTS CITY GAME 🎮 #shorts                          18
# WE TESTED VIRAL TIKTOK HACKS! #shorts                             18
# ...                                                              ...
# MEGA COMPILATION OF 5-MINUTE CRAFTS                            10740
# 100 CRAZY LIFE HACKS FOR ANY OCCASION                          11160
# 100 MUST-KNOW FOOD HACKS TO MAKE YOUR LIFE EASIER              11520
# 100 AWESOME KITCHEN LIFE HACKS || CRAZY COOKING...             12360
# REAL LIVE || Shooting Stunning Science Experiments             14880
#
#                                                     total_views  num_chars  \
# title
# ...

# %% [markdown]
# Los que no son outiliers

# %%
ubicacion_sin_outliers = (df['duration_seconds'] >= binferior_calculado) & (df["duration_seconds"] <= bsuperior_calculado)
ubicacion_sin_outliers = df[ubicacion_sin_outliers]
ubicacion_sin_outliers
# Out:
#                                                     duration_seconds  \
# title
# SUPER LAZY LIFE HACKS || Cool Hacks To Make You...               623
# YUM! EASY SMART FOOD HACKS || Tasty Recipes For...               739
# HELPFUL LIFE HACKS FOR YOUR HOUSE                                960
# USEFUL HACKS FOR YOUR HOME || Simple Tips That ...               833
# 30 BEST HACKS FOR EVERY LIFE SITUATION                           900
# ...                                                              ...
# Cheap & Easy Decorating Tricks - Home Decor Ide...               524
# 35 Science Experiments That Are Basically Magic...               746
# INCREDIBLE SCIENCE EXPERIMENTS l 5-MINUTE CRAFT...               900
# 25 Really Simple but Useful DIY Ticks l 5-MINUT...               561
# 5-MINUTE CRAFTS – Useful Ideas That You Didn't ...               599
#
#                                                     total_views  num_chars  \
# title
# ...

# %%
plt.title('Sin outliers')
plt.boxplot(ubicacion_sin_outliers['duration_seconds'],vert=False)

plt.show()

# %% [markdown]
# --------- DESPUÉS DE VER LA CLASE D EDA ------

# %% [markdown]
# FOTO

# %% [markdown]
# ### Importar librerias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ### Cargar datos

# %%
five_minute_crafts = pd.read_csv(filepath_or_buffer="/Users/luna/Desktop/posibles/5-Minute Crafts.csv")

# %% [markdown]
# ### Primera exploración

# %%
five_minute_crafts.head()
# Out:
#         video_id                                              title  \
# 0  v=XHTofu5wbbM  SUPER LAZY LIFE HACKS || Cool Hacks To Make Yo...
# 1  v=HGxx0umIQvk  YUM! EASY SMART FOOD HACKS || Tasty Recipes Fo...
# 2  v=Tt4RMk3Ih04                  HELPFUL LIFE HACKS FOR YOUR HOUSE
# 3  v=A2MTydM5e58  USEFUL HACKS FOR YOUR HOME || Simple Tips That...
# 4  v=_halJ4yrmGQ  ARE YOU A CRAFTY MOM? Amazing Parenting Hacks ...
#
#    active_since_days  duration_seconds  total_views  num_chars  num_words  \
# 0                 22               623       295614         60         12
# 1                  1               739       130544         87         17
# 2                  1               960        17834         33          6
# 3                 30               833      3128867         66         12
# 4                 15              3600      4210362         56         10
#
#    num_punctuation  num_words_uppercase  num_words_lowercase  num_stopwords  \
# ...

# %% [markdown]
# #### Notas con información de algunas columnas
#
# * Active_since_days: vídeo activo desde x días
# * Num_chars: caracteres totales del título del vídeo
# * Num_words: total de palabras en el título del vídeo
# * Num_punctuation: número de signos de puntuación
# * Num_words_uppercase: número de mayúsculas
# * Num_words_lowercase: número de minúsculas
# * Num_stopwords: "palabras vacías".Son palabras que para la recuperación de información y en el procesamiento del lenguaje natural debido a que no aporta un significado específico y no ayuda a distinguir un documento o fragmento de texto particular. Estas palabras suelen ser preposiciones, conjunciones, artículos y otros términos muy frecuentes en un idioma. Ejem: the, and,is,in,of...
# * Avg_word_len: longitud media de la palabra
# * Contain_digits: el título contiene dígitos
# * Startswith_digits: si el título empieza por un dígito
# * Title_sentiment: sentimiento del título del vídeo.  Significa lo positivo o negativo que es el título. Se calcula con la biblioteca textblob de python

# %%
five_minute_crafts.dtypes
# Out:
# video_id                object
# title                   object
# active_since_days        int64
# duration_seconds         int64
# total_views              int64
# num_chars                int64
# num_words                int64
# num_punctuation          int64
# num_words_uppercase      int64
# num_words_lowercase      int64
# num_stopwords            int64
# avg_word_len           float64
# contain_digits           int64
# startswith_digits        int64
# title_sentiment        float64
# dtype: object

# %%
five_minute_crafts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4978 entries, 0 to 4977
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             4978 non-null   object
#  1   title                4978 non-null   object
#  2   active_since_days    4978 non-null   int64
#  3   duration_seconds     4978 non-null   int64
#  4   total_views          4978 non-null   int64
#  5   num_chars            4978 non-null   int64
#  6   num_words            4978 non-null   int64
#  7   num_punctuation      4978 non-null   int64
#  8   num_words_uppercase  4978 non-null   int64
#  9   num_words_lowercase  4978 non-null   int64
#  10  num_stopwords        4978 non-null   int64
#  11  avg_word_len         4978 non-null   float64
#  12  contain_digits       4978 non-null   int64
#  13  startswith_digits    4978 non-null   int64
#  14  title_sentiment      4978 non-null   float64
# ...

# %%
five_minute_crafts.describe()
# Out:
#        active_since_days  duration_seconds   total_views    num_chars  \
# count        4978.000000       4978.000000  4.978000e+03  4978.000000
# mean          827.808759        932.421655  4.349619e+06    44.456408
# std           426.975866        727.392576  9.936944e+06    13.470281
# min             1.000000         11.000000  4.034000e+03    11.000000
# 25%           365.000000        696.000000  5.679352e+05    35.000000
# 50%           730.000000        867.000000  1.459397e+06    43.000000
# 75%          1095.000000        960.000000  4.271779e+06    52.000000
# max          1460.000000      14880.000000  2.830311e+08   100.000000
#
#          num_words  num_punctuation  num_words_uppercase  num_words_lowercase  \
# count  4978.000000      4978.000000          4978.000000          4978.000000
# mean      8.208718         0.495982             6.138610             0.287264
# std       2.516098         0.901010             2.546744             1.355098
# ...

# %%
five_minute_crafts.shape
# Out:
# (4978, 15)

# %%
five_minute_crafts.columns
# Out:
# Index(['video_id', 'title', 'active_since_days', 'duration_seconds',
#        'total_views', 'num_chars', 'num_words', 'num_punctuation',
#        'num_words_uppercase', 'num_words_lowercase', 'num_stopwords',
#        'avg_word_len', 'contain_digits', 'startswith_digits',
#        'title_sentiment'],
#       dtype='object')

# %%
sns.pairplot(five_minute_crafts)

# %% [markdown]
# * media 0
# * deviación estandar 1

# %%
plt.figure(figsize=(3,2))
sns.pairplot(five_minute_crafts);

# %%
for i in five_minute_crafts.select_dtypes(include=object):
    print(f"La cardinalidad de la variable {i} es {(five_minute_crafts[i].nunique()/five_minute_crafts.shape[0])*100:.2f}%")
# Out:
# La cardinalidad de la variable video_id es 100.00%
# La cardinalidad de la variable title es 99.74%

# %%
sns.pairplot(five_minute_crafts, kind='scatter', hue='video_id',
            plot_kws=dict(s=80, edgecolor='white',linewidth=2.5));
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Bootcamp/.venv/lib/python3.11/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/Documents/Bootcamp/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# ...

# %% [markdown]
# ### Hipótesis
#
# ##### Estadísticas
#
# * Algunas palabras o frases específicas pueden atraer más atención y generar más visitas.
# * El uso de palabras clave que sugieran acción, por ejemplo: "hazlo tú mismo", "aprende", "descubre", puede estar asociado con un aumento en las visitas.
# * La proporción de palabras en mayúsculas y minúsculas en el título puede estar relacionada con la cantidad de visitas al video.
# * Distribución de normalidad
#
#
#
# * La longitud de la palabra clave en el título de un video está correlacionada con el número de visitas que recibe:
#
# Gráfico de dispersión: Puedes crear un gráfico de dispersión con la longitud de la palabra clave en el eje x y el número de visitas en el eje y. Cada punto en el gráfico representaría un video. Esto te permitirá visualizar cualquier patrón o tendencia.
#
# Gráfico de barras o caja y bigote: Puedes agrupar los videos según rangos de longitud de palabra clave y mostrar el número medio de visitas en cada grupo. Esto puede proporcionar una visión más clara de la relación entre la longitud de la palabra clave y las visitas.
#
# * Existe una correlación entre la duración de un video con el número total de visitas que recibe:
#
# Gráfico de dispersión: Similar al caso anterior, un gráfico de dispersión puede mostrar la relación entre la duración del video y el número de visitas.
#
#
# * El sentimiento del título puede influir en el nivel de popularidad y número de visitas:
#
# Histograma de Sentimientos: Crea un histograma que muestre la distribución de sentimientos en los títulos de tus videos. Puedes utilizar una escala de colores para representar diferentes emociones (positivas, neutrales, negativas).
#
# Mapa de Calor:Un mapa de calor puede representar visualmente la intensidad de ciertos sentimientos en los títulos. Puedes asignar colores más intensos a emociones más fuertes.
#
# * Grafico de Normalidad

# %% [markdown]
# ### Limpieza
